# %%
file_path = 'input'

sequences = []

with open(file_path, 'r') as file:
    lines = file.readlines()

for line in lines:
    line_temp = line.strip().split()
    line_divided = []
    for element in line_temp[0]:
        line_divided.append(int(element))
    sequences.append(line_divided)

total = 0

for sequence in sequences:
    found = False

    for i00 in range(9, 0, -1):
        try:
            pos_00 = sequence.index(i00)
        except ValueError:
            continue

        if found:
            break
        
        for i01 in range(9, 0, -1):
            try:
                pos_01 = sequence[pos_00+1:].index(i01)
            except ValueError:
                continue

            if found:
                break

            for i02 in range(9, 0, -1):
                try:
                    pos_02 = sequence[pos_00+pos_01+2:].index(i02)
                except ValueError:
                    continue

                if found:
                    break

                for i03 in range(9, 0, -1):
                    try:
                        pos_03 = sequence[pos_00+pos_01+pos_02+3:].index(i03)
                    except ValueError:
                        continue

                    if found:
                        break

                    for i04 in range(9, 0, -1):
                        try:
                            pos_04 = sequence[pos_00+pos_01+pos_02+pos_03+4:].index(i04)
                        except ValueError:
                            continue

                        if found:
                            break

                        for i05 in range(9, 0, -1):
                            try:
                                pos_05 = sequence[pos_00+pos_01+pos_02+pos_03+pos_04+5:].index(i05)
                            except ValueError:
                                continue

                            if found:
                                break

                            for i06 in range(9, 0, -1):
                                try:
                                    pos_06 = sequence[pos_00+pos_01+pos_02+pos_03+pos_04+pos_05+6:].index(i06)
                                except ValueError:
                                    continue

                                if found:
                                    break

                                for i07 in range(9, 0, -1):
                                    try:
                                        pos_07 = sequence[pos_00+pos_01+pos_02+pos_03+pos_04+pos_05+pos_06+7:].index(i07)
                                    except ValueError:
                                        continue

                                    if found:
                                        break

                                    for i08 in range(9, 0, -1):
                                        try:
                                            pos_08 = sequence[pos_00+pos_01+pos_02+pos_03+pos_04+pos_05+pos_06+pos_07+8:].index(i08)
                                        except ValueError:
                                            continue

                                        if found:
                                            break

                                        for i09 in range(9, 0, -1):
                                            try:
                                                pos_09 = sequence[pos_00+pos_01+pos_02+pos_03+pos_04+pos_05+pos_06+pos_07+pos_08+9:].index(i09)
                                            except ValueError:
                                                continue

                                            if found:
                                                break

                                            for i10 in range(9, 0, -1):
                                                try:
                                                    pos_10 = sequence[pos_00+pos_01+pos_02+pos_03+pos_04+pos_05+pos_06+pos_07+pos_08+pos_09+10:].index(i10)
                                                except ValueError:
                                                    continue

                                                if found:
                                                    break

                                                for i11 in range(9, 0, -1):
                                                    try:
                                                        pos_11 = sequence[pos_00+pos_01+pos_02+pos_03+pos_04+pos_05+pos_06+pos_07+pos_08+pos_09+pos_10+11:].index(i11)
                                                    except ValueError:
                                                        continue
                                                    total += int(100000000000*i00+10000000000*i01+1000000000*i02+100000000*i03+10000000*i04+1000000*i05+100000*i06+10000*i07+1000*i08+100*i09+10*i10+i11)
                                                    found = True
                                                    break


print(total)
# Out:
# 176582889354075
